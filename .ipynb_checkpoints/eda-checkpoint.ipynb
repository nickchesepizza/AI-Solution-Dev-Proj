# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load the Database using sqlite

# %%
import sqlite3
import pandas as pd

# 1. Create a connection to the database
conn = sqlite3.connect('/content/drive/MyDrive/Y3 S1/AI solution dev pj/Project/data/gas_monitoring.db')

# 2. Query to find all the table names in the database
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

print("Tables in the database:", tables)
# Out:
# Tables in the database: [('gas_monitoring',)]

# %% [markdown]
# # Extract the Data into a DataFrame

# %%
# Replace 'sensor_data' with the actual table name you found in Step 1
query = "SELECT * FROM gas_monitoring"

# Load the data into a Pandas DataFrame
df = pd.read_sql_query(query, conn)

# Close the connection since we have the data in memory now
conn.close()

# Look at the first 5 rows to see what you're dealing with
display(df.head())
# Out:
#   Time of Day  Temperature  Humidity  CO2_InfraredSensor  \
# 0     morning        19.63     53.83          125.486389
# 1     morning       292.81     53.69          126.343018
# 2     morning        19.62     54.25          126.560695
# 3     morning        20.10     50.48          113.504877
# 4     morning        19.89     48.42           92.766225
#
#    CO2_ElectroChemicalSensor  MetalOxideSensor_Unit1  MetalOxideSensor_Unit2  \
# 0                 571.089440              478.554958              735.850412
# 1                 575.789501              491.955151              740.282738
# 2                 585.543111              505.560808              737.112906
# 3                 597.449961              515.142272              744.020651
# 4                 613.654875              535.664558              770.265441
#
#    MetalOxideSensor_Unit3  MetalOxideSensor_Unit4  CO_GasSensor  Session ID  \
# 0              654.625253              565.051969           2.0        7241
# ...

# %% [markdown]
# # The "Sanity Check"

# %% [markdown]
# Checking the missing values in the dataframe

# %% [markdown]
# After checking, we found out that there are many missing values, impossible outliers like having 300 degrees in temperature and -49% in humidity.

# %%
# Check the shape (number of rows and columns)
print(f"Dataset contains {df.shape[0]} rows and {df.shape[1]} columns.\n")

# Check data types and look for missing (null) values
print("--- Data Info ---")
df.info()

# Get a statistical summary to spot obvious outliers
# (e.g., a room temperature of 999 degrees)
display(df.describe())
# Out:
# Dataset contains 10000 rows and 14 columns.
#
# --- Data Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Time of Day                10000 non-null  object
#  1   Temperature                10000 non-null  float64
#  2   Humidity                   8072 non-null   float64
#  3   CO2_InfraredSensor         10000 non-null  float64
#  4   CO2_ElectroChemicalSensor  10000 non-null  float64
#  5   MetalOxideSensor_Unit1     10000 non-null  float64
#  6   MetalOxideSensor_Unit2     8590 non-null   float64
#  7   MetalOxideSensor_Unit3     10000 non-null  float64
#  8   MetalOxideSensor_Unit4     10000 non-null  float64
#  9   CO_GasSensor               9166 non-null   float64
#  10  Session ID                 10000 non-null  int64
#  11  HVAC Operation Mode        10000 non-null  object
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Remove extreme outliers but it will also remove the null since the method is to remove everything which is not in the range.

# %%
# Document assumption: Negative gases/light and extreme temps are sensor errors.
df_filtered = df[
    (df['Temperature'] >= 10) & (df['Temperature'] <= 40) &
    (df['Humidity'] >= 0) & (df['Humidity'] <= 100) &
    (df['CO2_InfraredSensor'] >= 0) & (df['CO2_InfraredSensor'] <= 10000) &
    (df['CO2_ElectroChemicalSensor'] >= 0) & (df['CO2_ElectroChemicalSensor'] <= 10000) &
    (df['CO_GasSensor'] >= 0) & (df['CO_GasSensor'] <= 2000) &
    (df['MetalOxideSensor_Unit1'] >= 0) &
    (df['MetalOxideSensor_Unit2'] >= 0) &
    (df['MetalOxideSensor_Unit3'] >= 0) &
    (df['MetalOxideSensor_Unit4'] >= 0)
].copy()

# Filtering for Metal Oxide Sensors (Removing the top 1% as glitches)
# We calculate the 99th percentile and keep only data below it
for col in ['MetalOxideSensor_Unit1', 'MetalOxideSensor_Unit2', 'MetalOxideSensor_Unit3', 'MetalOxideSensor_Unit4']:
    cap_value = df_filtered[col].quantile(0.99)
    df_filtered = df_filtered[df_filtered[col] <= cap_value]

print(f"Original rows: {len(df)}")
print(f"Rows after comprehensive outlier removal: {len(df_filtered)}")
# Out:
# Original rows: 10000
# Rows after comprehensive outlier removal: 5238

# %% [markdown]
# Filling Null (Missing) Values with the mode

# %%
#Check for missing values before imputation
print(df_filtered.isnull().sum())
# Out:
# Time of Day                    0
# Temperature                    0
# Humidity                       0
# CO2_InfraredSensor             0
# CO2_ElectroChemicalSensor      0
# MetalOxideSensor_Unit1         0
# MetalOxideSensor_Unit2         0
# MetalOxideSensor_Unit3         0
# MetalOxideSensor_Unit4         0
# CO_GasSensor                   0
# Session ID                     0
# HVAC Operation Mode            0
# Ambient Light Level          570
# Activity Level                 0
# dtype: int64

# %% [markdown]
# Do .info to check the number is correct or not

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5238 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Time of Day                5238 non-null   object
#  1   Temperature                5238 non-null   float64
#  2   Humidity                   5238 non-null   float64
#  3   CO2_InfraredSensor         5238 non-null   float64
#  4   CO2_ElectroChemicalSensor  5238 non-null   float64
#  5   MetalOxideSensor_Unit1     5238 non-null   float64
#  6   MetalOxideSensor_Unit2     5238 non-null   float64
#  7   MetalOxideSensor_Unit3     5238 non-null   float64
#  8   MetalOxideSensor_Unit4     5238 non-null   float64
#  9   CO_GasSensor               5238 non-null   float64
#  10  Session ID                 5238 non-null   int64
#  11  HVAC Operation Mode        5238 non-null   object
#  12  Ambient Light Level        4668 non-null   object
# ...

# %% [markdown]
# Since Ambient Light Level is missing 570 rows so I filled with the mode which is most frequently appeared in the database.

# %%
# Calculate the mode (most common category) for Ambient Light Level
light_mode = df_filtered['Ambient Light Level'].mode()[0]

# Fill the missing values with the mode
df_filtered['Ambient Light Level'] = df_filtered['Ambient Light Level'].fillna(light_mode)

# Final Sanity Check to ensure everything is at 0
print("Missing values after filling Ambient Light Level:")
print(df_filtered.isnull().sum())
# Out:
# Missing values after filling Ambient Light Level:
# Time of Day                  0
# Temperature                  0
# Humidity                     0
# CO2_InfraredSensor           0
# CO2_ElectroChemicalSensor    0
# MetalOxideSensor_Unit1       0
# MetalOxideSensor_Unit2       0
# MetalOxideSensor_Unit3       0
# MetalOxideSensor_Unit4       0
# CO_GasSensor                 0
# Session ID                   0
# HVAC Operation Mode          0
# Ambient Light Level          0
# Activity Level               0
# dtype: int64

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5238 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Time of Day                5238 non-null   object
#  1   Temperature                5238 non-null   float64
#  2   Humidity                   5238 non-null   float64
#  3   CO2_InfraredSensor         5238 non-null   float64
#  4   CO2_ElectroChemicalSensor  5238 non-null   float64
#  5   MetalOxideSensor_Unit1     5238 non-null   float64
#  6   MetalOxideSensor_Unit2     5238 non-null   float64
#  7   MetalOxideSensor_Unit3     5238 non-null   float64
#  8   MetalOxideSensor_Unit4     5238 non-null   float64
#  9   CO_GasSensor               5238 non-null   float64
#  10  Session ID                 5238 non-null   int64
#  11  HVAC Operation Mode        5238 non-null   object
#  12  Ambient Light Level        5238 non-null   object
# ...
